# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/scraped_data (2).csv')  # Change this to your file path

# %%
# First look at the data
print("First 5 rows:")
df.head(5)
# Out:
# First 5 rows:
#          Name  Price              Link  \
# 0   Charizard   63.0  #site-navigation
# 1  Charmeleon   87.0  #site-navigation
# 2     Metapod  105.0  #site-navigation
# 3    Venusaur   48.0  #site-navigation
# 4   Pidgeotto  165.0  #site-navigation
#
#                                          Description  Availability
# 0  Bulbasaur can be seen napping in bright sunlig...   45 in stock
# 1  There is a bud on this Pokémon’s back. To supp...  142 in stock
# 2  There is a large flower on Venusaur’s back. Th...   30 in stock
# 3  The flame that burns at the tip of its tail is...  206 in stock
# 4  Charmeleon mercilessly destroys its foes using...  284 in stock

# %%
# General info about the dataset
print("Dataset info:")
print(df.info())
# Out:
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          755 non-null    object
#  1   Price         755 non-null    float64
#  2   Link          755 non-null    object
#  3   Description   755 non-null    object
#  4   Availability  755 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 29.6+ KB
# None

# %%
# Summary statistics
print("Summary statistics:")
df.describe()
# Out:
# Summary statistics:
#             Price
# count  755.000000
# mean   110.948344
# std     51.702359
# min     25.000000
# 25%     66.000000
# 50%    111.000000
# 75%    157.000000
# max    200.000000

# %%
# Check for missing values
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Name            0
# Price           0
# Link            0
# Description     0
# Availability    0
# dtype: int64

# %%
# Remove £ symbol and convert to float
df['Price'] = df['Price'].replace('[£,]', '', regex=True).astype(float)

# %%
df.shape
# Out:
# (755, 5)

# %%
df.hist(bins=30, figsize=(15, 10), color='skyblue')
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
# Boxplots for detecting outliers
for col in df.select_dtypes(include=['float64', 'int64']):
    plt.figure()
    sns.boxplot(x=df[col], color='lightcoral')
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    plt.figure()
    sns.countplot(data=df, x=col, palette='Set2')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipython-input-1038485849.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /tmp/ipython-input-1038485849.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /tmp/ipython-input-1038485849.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /tmp/ipython-input-1038485849.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
